# %%
import torch
print(torch.cuda.is_available())         # True if CUDA usable
print(torch.cuda.device_count())        # how many GPUs
print(torch.cuda.get_device_name(0))    # name of first GPU (if exists)
# Out:
# True
# 1
# NVIDIA GeForce RTX 4080
